# %% [markdown]
# # First Data Science Project
# ## Melbourne Housing Prices Prediction
# Here, we will go through a data challenge using data predicting housing prices in Melbourne, Australia.
#
# The data is from Kaggle and can be found [here](https://www.kaggle.com/anthonypino/melbourne-housing-market)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Collection

# %%
full_data = pd.read_csv("./data/Melbourne_housing_FULL.csv")
full_data
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
y = full_data.loc[:, "Price"]
X = full_data.drop(columns=["Price"])

# %%
train_size = 0.8
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=train_size, random_state=42)

# %%
X.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Method', 'SellerG', 'Date',
#        'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude',
#        'Regionname', 'Propertycount'],
#       dtype='object')

# %%
import sys
# !{sys.executable} -m pip install -U pandas-profiling[notebook]
# !jupyter nbextension enable --py widgetsnbextension

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(X)
profile.to_file(output_file="your_report.html")
# Out:
# ...
# ---------------------------------------------------------------------------
# TerminatedWorkerError                     Traceback (most recent call last)
# <ipython-input-184-16d54b174cf0> in <module>
#       1 from pandas_profiling import ProfileReport
#       2 profile = ProfileReport(X)
# ----> 3 profile.to_file(output_file="your_report.html")
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in to_file(self, output_file, silent)
#     255                 create_html_assets(self.config, output_file)
#     256
# --> 257             data = self.to_html()
#     258
#     259             if output_file.suffix != ".html":
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in to_html(self)
#     366
#     367         """
# --> 368         return self.html
#     369
#     370     def to_json(self) -> str:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas_profiling/profile_report.py in html(self)
# ...

# %%
#data types of columns
full_data.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
columns = ['Suburb', 'Address', 'SellerG', 'CouncilArea', 'Regionname', 'Date', 'Longtitude', 'Lattitude']
drop_full_data = X_train.drop(columns = columns)

# %%
drop_full_data.columns
# Out:
# Index(['Rooms', 'Type', 'Method', 'Distance', 'Postcode', 'Bedroom2',
#        'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt',
#        'Propertycount'],
#       dtype='object')

# %%
dummies_full_data = pd.get_dummies(drop_full_data)

# %%
dummies_full_data
# Out:
#        Rooms  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 20967      4      13.8    3165.0       4.0       2.0  2.0     648.0
# 26014      4      13.8    3188.0       4.0       2.0  2.0     662.0
# 20468      4      20.6    3064.0       4.0       1.0  0.0     641.0
# 19303      2      10.5    3186.0       2.0       1.0  1.0     100.0
# 6672       2       2.8    3000.0       NaN       NaN  NaN       NaN
# ...      ...       ...       ...       ...       ...  ...       ...
# 16850      3      24.7    3175.0       3.0       1.0  1.0     810.0
# 6265       2       7.4    3144.0       NaN       NaN  NaN       NaN
# 11284      4      12.4    3060.0       4.0       2.0  2.0     647.0
# 860        5       9.7    3103.0       5.0       3.0  2.0     600.0
# 15795      5      17.2    3132.0       5.0       2.0  2.0     760.0
#
#        BuildingArea  YearBuilt  Propertycount  ...  Type_u  Method_PI  \
# 20967           NaN        NaN        10969.0  ...       0          0
# ...

# %%
dummies_full_data['Car']=dummies_full_data['Car'].fillna(dummies_full_data['Car'].mode()[0])
dummies_full_data['Bathroom']=dummies_full_data['Bathroom'].fillna(dummies_full_data['Bathroom'].mode()[0])
#dummies_full_data['Bedroom2']=dummies_full_data['Bedroom2'].fillna(dummies_full_data['Bedroom2'].mode()[0])
dummies_full_data['Landsize']=dummies_full_data['Landsize'].fillna(dummies_full_data['Landsize'].mode()[0])
dummies_full_data['BuildingArea']=dummies_full_data['BuildingArea'].fillna(dummies_full_data['BuildingArea'].mode()[0])
dummies_full_data['YearBuilt']=dummies_full_data['YearBuilt'].fillna(dummies_full_data['YearBuilt'].mode()[0])
dummies_full_data['Distance']=dummies_full_data['Distance'].fillna(dummies_full_data['Distance'].mode()[0])
dummies_full_data['Propertycount']=dummies_full_data['Propertycount'].fillna(dummies_full_data['Propertycount'].mode()[0])
dummies_full_data['Postcode']=dummies_full_data['Postcode'].fillna(dummies_full_data['Postcode'].mode()[0])

# %%
dummies_full_data['b 2 r'] = dummies_full_data["Bedroom2"] - full_data["Rooms"]
dummies_full_data = dummies_full_data.drop(['b 2 r', 'Bedroom2'], 1)

# %%
dummies_full_data  = dummies_full_data [dummies_full_data ['BuildingArea']!=0]
dummies_full_data
# Out:
#        Rooms  Distance  Postcode  Bathroom  Car  Landsize  BuildingArea  \
# 20967      4      13.8    3165.0       2.0  2.0     648.0         120.0
# 26014      4      13.8    3188.0       2.0  2.0     662.0         180.0
# 20468      4      20.6    3064.0       1.0  0.0     641.0         110.0
# 19303      2      10.5    3186.0       1.0  1.0     100.0         110.0
# 6672       2       2.8    3000.0       1.0  2.0       0.0         120.0
# ...      ...       ...       ...       ...  ...       ...           ...
# 16850      3      24.7    3175.0       1.0  1.0     810.0         120.0
# 6265       2       7.4    3144.0       1.0  2.0       0.0         120.0
# 11284      4      12.4    3060.0       2.0  2.0     647.0         120.0
# 860        5       9.7    3103.0       3.0  2.0     600.0         356.0
# 15795      5      17.2    3132.0       2.0  2.0     760.0         240.0
#
#        YearBuilt  Propertycount  Type_h  ...  Type_u  Method_PI  Method_PN  \
# ...

# %%
dummies_full_data.isna().sum()
# Out:
# Rooms            0
# Distance         0
# Postcode         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# Propertycount    0
# Type_h           0
# Type_t           0
# Type_u           0
# Method_PI        0
# Method_PN        0
# Method_S         0
# Method_SA        0
# Method_SN        0
# Method_SP        0
# Method_SS        0
# Method_VB        0
# Method_W         0
# dtype: int64

# %% [markdown]
# ## 2. Cleaning

# %% [markdown]
# - drop: address,
# - type: keep as categories -> dummies
# - method: keep as categories -> dummies
# - rooms: there is bedrooms which are very similar
# - sellerG: replace other values as other and turn into dummies
# - distance: log transform
# - date: turn it into timestamp
# - postcode: drop
# - bedrooms: drop or kNN imputer for the missing values
# - bathroom: deal with outliers
# - car: turn to categorical
# - landsize: deal with outliers
# - buildingarea: knn imputer
# - yearbuilt: deal with outliers
# - council area: do others call others
# - longandlandtitude: keep
# - regionname: name others as others
# - propertycount: keep
# - price: missing values to drop

# %%
# # change date to datetime
# full_data['Date'] = pd.to_datetime(full_data['Date'])
# full_data.dtypes

# %%
dummies_full_data.dtypes
# Out:
# Rooms              int64
# Distance         float64
# Postcode         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# Propertycount    float64
# Type_h             uint8
# Type_t             uint8
# Type_u             uint8
# Method_PI          uint8
# Method_PN          uint8
# Method_S           uint8
# Method_SA          uint8
# Method_SN          uint8
# Method_SP          uint8
# Method_SS          uint8
# Method_VB          uint8
# Method_W           uint8
# dtype: object

# %%
dummies_full_data = dummies_full_data.replace([np.inf, -np.inf], np.nan)

# %%
np.all(np.isfinite(dummies_full_data))
# Out:
# True

# %%
y
# Out:
# 0              NaN
# 1        1480000.0
# 2        1035000.0
# 3              NaN
# 4        1465000.0
#            ...
# 34852    1480000.0
# 34853     888000.0
# 34854     705000.0
# 34855    1140000.0
# 34856    1020000.0
# Name: Price, Length: 34857, dtype: float64

# %%
y['Price']=y['Price'].fillna(y['Price'].mode()[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-203-c89056367ad1> in <module>
# ----> 1 y['Price']=y['Price'].fillna(y['Price'].mode()[0])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880     @Appender(generic.NDFrame.take.__doc__)
#     881     def take(self, indices, axis=0, is_copy=None, **kwargs) -> Series:
# --> 882         if is_copy is not None:
#     883             warnings.warn(
#     884                 "is_copy is deprecated and will be removed in a future version. "
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     987         if not isinstance(key, (list, np.ndarray, ExtensionArray, Series, Index)):
#     988             key = list(key)
# --> 989
#     990         if isinstance(key, Index):
# ...

# %%
# Import model
from sklearn.linear_model import LinearRegression

# Create linear regression object
regressor = LinearRegression()

# Fit model to training data
regressor.fit(dummies_full_data,y)

# %%
np.any(np.isnan(dummies_full_data))

# %%
# Predict
# Predicting test set results
y_pred = regressor.predict(X_test)

# %%
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,y_pred))
print('MSE:',metrics.mean_squared_error(y_test,y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))

# %%
print('R^2 =',metrics.explained_variance_score(y_test,y_pred))

# %%
# Actual v predictions scatter
plt.scatter(y_test, y_pred)

# %%
cdf = pd.DataFrame(data = regressor.coef_, index = X.columns, columns = ['Coefficients'])
cdf

# %%
cross val score from model_selection on the training data

# %% [markdown]
# ## 4. Model Building

# %% [markdown]
# ## 5. Iterating
